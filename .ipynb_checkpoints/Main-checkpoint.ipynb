# %% [markdown]
# # Utilisation de la base de données

# %%
import sqlite3
from chess_functions import *
from stats import *

# %% [markdown]
# Connexion à la base de données

# %%
con = sqlite3.connect('MyDataBase.db')

# %% [markdown]
# Update de la base de données

# %%
update(60000, con)

# %% [markdown]
# Enregistrement des données

# %%
con.commit()

# %% [markdown]
# __Tests sur un joueur nommé Herve Daurelle__

# %%
joueur = 'daurelle herve'

# %% [markdown]
# Réussite, nul ou défaite selon l'adversaire (adversaires rencontrés 2 fois minimum)

# %%
top_adversaires(con, joueur)
# Out:
# 1961

# %% [markdown]
# Réussite et défaite selon la couleur jouée

# %%
victoire_couleur(joueur, con)
# Out:
# 1961

# %% [markdown]
# Evolution du elo du joueur au cours des matchs

# %%
elo_evolution(con, joueur)

# %% [markdown]
# Nombre de matchs joués par mois au cours du temps

# %%
number_match(con, joueur)
# Out:
# 1961

# %% [markdown]
# Affichage de tous les tournois auxquels le joueur a participés entre le 1 juillet 2012 et le 1 septembre 2020

# %%
matchs = matchs_period(con, joueur, datetime(2012, 7, 1), datetime(2020, 9, 1))
# Out:
# 1961
# 9ème open international de Plancoët
# Championnat de Paris Ile de France 2012 Open Fide (>=2200)
# 20ème open international de Saint-Affrique
# 155eme open FIDE du club 608
# 156eme open FIDE du club 608 (-2200 elo)
# 157eme open FIDE du club 608 (-2200 elo)
# 54e Open Fide Chess XV Groupe A (+1700 elo)
# Championnat de France 2012 - Accession
# 55e Open Fide Chess XV Groupe A (1800-2199)
# 56e Open Fide Chess XV Groupe A (1700-2199)
# 160e open FIDE du club 608 d'echecs (-2200)
# 23e Open Rapide de Franconville (-2350 elo)
# 9ème tournoi de parties rapides du Vésinet
# 1er Open de la Toussaint de Lille
# 12e Open international de Malakoff
# 12eme Festival de Rochefort - Masters
# 4ème LUCOPEN : Tournoi International d'Echecs de Lille
# 37e Open International de Fourmies
# Bois-Colombes Chess Master 2012 - Open A
# 29e open international de Cappelle-la-Grande
# 10e Open international de Plancoët
# 6e Open International de Cambrai
# Championnat de France 2013 - Open A
# 2e Grand Prix des Pyramides de Port-Marly - Trophée Kaissa
# 5th Chess Open Tour de Juvisy
# 166e open FIDE du club 608 d'echecs
# XXXIe Open International d'échecs de Metz - Open A
# 36e Open de l'Ascension Victor SYRE d'Issy-les-Moulineaux
# 173e open FIDE du club 608 d'echecs
# 175e open FIDE du club 608 d'echecs (-2200)
# 77e Open Fide Chess XV - Tournoi A (+1700 )
# 25eme Open International d'été de la Ville de Cannes
# 11e Open international de Plancoët
# Championnat de France Trophée BNP-PARIBAS 2013
# 24e Open Franconville
# 34e Open International d'Echecs de Bethune - Tournoi C
# Championnat départemental d'échecs des écoles de Moselle
# 28eme Open du Mans
# 12è Rencontres Internationales du Cap d'Agde - Tournoi de l'Avenir
# 8ème Rapide d'Yffiniac Toutes Catégories
# 23° tournoi d'échecs de l'ABC Pays de Vannes  Baden Tournoi principal
# open rapide de Guichen - tournoi principal
# 1er Rapide Jeunes Orsay Échecs
# Championnat de l'Essonne 2017 poussins
# Championnat départemental des écoles de l'Essonne 2017-2018
# Championnat de Corse 2018 Petits-Poussins
# Championnat Scolaire 2018/2019 Collèges 29N phase 1
# Zonal Scolaire de Hyéres 2018

# %% [markdown]
# Informations reliés au joueur pour le tournoi nommé "23e Open Rapide de Franconville (-2350 elo)"

# %%
infos = infos_joueur_tournoi(con, joueur, "23e Open Rapide de Franconville (-2350 elo)")
# Out:
# 1961
# 24846
# sochacki wojtek contre daurelle herve ------>  winner : ex aequo
# tamburro clemence contre daurelle herve ------>  winner (blanc) : daurelle herve
# daurelle herve contre appavou calixte ------>  winner (noir) : daurelle herve
# vidal guillaume contre daurelle herve ------>  winner (blanc) : daurelle herve
# daurelle herve contre simon olivier ------>  winner (noir) : daurelle herve
# jablonski noham contre daurelle herve ------>  winner : ex aequo
# daurelle herve contre veron cyprien ------>  winner : ex aequo
# pietrasanta jeremy contre daurelle herve ------>  winner (blanc) : daurelle herve
# daurelle herve contre kambrath yannick ------>  winner : ex aequo
